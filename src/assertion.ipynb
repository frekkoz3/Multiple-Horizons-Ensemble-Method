# %%
from litellm import config_path

from data_handler import *
from config_files import *
from direct_model import *
from mheme import *

import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/solar.csv')

# %%
X = data['power_mw']

# %%
X_slide, y_slide = sliding_window(X.to_numpy(), window=24, horizon=12)
train, val, test = train_validation_test_split(X_slide, y_slide)

# %%
print(f"train: {train}\nval: {val}\ntest: {test}")
# Out:
# train: 2
# val: 2
# test: 2

# %%
config_path = './config_files/tcn_config.json'
# Out:
# Training TCN:   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 3
#       1 config_path = './config_files/tcn_config.json'
#       2 model = TCN(config_path)
# ----> 3 model.fit(train[0], train[1])
#
# File D:\university\statistical_methods\project\src\direct_model.py:139, in TCN.fit(self, X, y)
#     137 # Forward Pass
#     138 self.optim.zero_grad()
# --> 139 y_hat = self(batch_X)
#     141 # Compute Loss
#     142 loss = self.loss(y_hat, batch_y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File D:\university\statistical_methods\project\src\direct_model.py:112, in TCN.forward(self, x)
#     110 def forward(self, x):
#     111     for conv_layer in self.conv_layers:
# --> 112         x = self.activation(conv_layer(x))
#     113     x = x[:, :, -1]
#     114     x = self.readout(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# RuntimeError: Given groups=1, weight of size [8, 16, 3], expected input[32, 8, 24] to have 16 channels, but got 8 channels instead
